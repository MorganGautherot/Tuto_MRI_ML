# %% [markdown]
# ## La régression

# %% [markdown]
# Le but de la régression est de créer un modèle qui va savoir estimer une variable continue.
#
# Nous allons donner à l'algorithme des données avec les valeurs réelles de la variable à prédire. Pendant l'entraînement, l'algorithme va apprendre à reconnaître la distribution de la variable à prédire ainsi que les caractéristiques qui vont permettre au modèle d'estimer avec le moins d'erreur possible notre cible.

# %% [markdown]
# ## La régression en radiologie

# %% [markdown]
# L'âge d'une personne peut être une variable difficile à déterminé lors d'un examen clinique. Le but de cette étude, est d'estimer le plus précisément possible l'âge d'un individu en partant de sont IRM pondérée T1.

# %% [markdown]
# ### Importation des packages

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import nibabel
import sys
import os
import datetime

# Model architecture

from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv3D, MaxPooling3D
from tensorflow.keras.layers import ReLU, PReLU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.losses import mean_squared_error
from tensorflow.keras.optimizers import SGD, RMSprop
from tensorflow.keras.callbacks import Callback, LearningRateScheduler, ModelCheckpoint


from keras.callbacks import Callback


import nibabel as nib
import seaborn as sns
from scipy.signal import find_peaks
# Out:
# Using TensorFlow backend.

# %%
# own bibli
sys.path.append("data/utils/")
from callbacks import SaveHyperparameters, SaveMetrics
from utils import train_test_val
from models import model_Cole
from generators import generator_mri_regression

# %% [markdown]
# ### Importation des hyperparamètres

# %%
SIZE = (193, 229, 193, 1)
LEARNING_RATE = 0.001

# %% [markdown]
# ### Importation des données

# %% [markdown]
# Importation de nos jeux d'entraînement. Comme vous pouvez le voir ci-dessous, ce jeu de données contient tous les liens où l'on peut trouver nos images ainsi que des informations à propos de nos images.

# %%
data_train = pd.read_csv('data/train.csv')
data_train.head()
# Out:
#     id         sub                                                 t1  \
# 0   21     sub-021  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 1  276  sub-IXI276  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 2  129     sub-129  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 3   94  sub-IXI094  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 4  619     sub-619  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
#
#                                              t1_norm  \
# 0  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 1  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 2  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 3  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 4  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
#
#                                           hippo_mask  \
# 0  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 1  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 2  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 3  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 4  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
#
#                                              gm_mask  \
# 0  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 1  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 2  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 3  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 4  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
#
#                                              wm_mask  \
# 0  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 1  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 2  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 3  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 4  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
#
#                                           brain_mask  sex   age
# 0  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...    1  21.0
# 1  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...    0  20.0
# 2  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...    0  23.0
# 3  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...    0  24.0
# 4  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...    0  24.0

# %% [markdown]
# Vous pouvez voir ci-dessous la distribution de l'âge du jeu d'entraînement.
#
# <img src='data/distrib_age_train.png' >

# %% [markdown]
# Importation de nos jeux de test. Comme vous pouvez le voir ci-dessous, ce jeu de données contient tous les liens où l'on peut trouver nos images ainsi que des informations à propos de nos images.

# %%
data_test = pd.read_csv('data/test.csv')
data_test.head()
# Out:
#           sub                                                 t1  \
# 0  sub-IXI331  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 1     sub-064  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 2  sub-IXI426  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 3  sub-IXI230  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 4  sub-IXI201  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
#
#                                              t1_norm  \
# 0  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 1  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 2  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 3  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 4  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
#
#                                           hippo_mask  \
# 0  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 1  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 2  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 3  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 4  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
#
#                                              gm_mask  \
# 0  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 1  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 2  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 3  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 4  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
#
#                                              wm_mask  \
# 0  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 1  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 2  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 3  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
# 4  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...
#
#                                           brain_mask  sex   age
# 0  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...    0  23.0
# 1  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...    0  20.0
# 2  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...    1  23.0
# 3  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...    1  21.0
# 4  /NAS/deathrow/morgan/bids_proc/IXI/freesurfer/...    1  22.0

# %% [markdown]
# Vous pouvez voir ci-dessous la distribution de l'âge du jeu de test.
#
# <img src='data/distrib_age_test.png' >

# %% [markdown]
# Les intensités de nos images IRM ont été normalisé par la technique vue dans le notebook 2.
#
# On est passé de cette représentation de nos intensité pour les données d'entraînement :
#
# <img src='data/t1_unnorm_distribution.png' >
#
# A cette distribution d'intensité après normalisation :
#
#
# <img src='data/t1_norm_distribution.png' >

# %% [markdown]
# Souvent en deep learning les jeux d'entraînement et de test sont trop gros pour être charger en mémoire.
#
# Pour entraîner nos modèles nous sommes obligé d'entraîner nos modèles par mini-batch. Un batch est une fraction de notre jeu d'entraînement.
#
# <img src='data/mini-batch.png' >
#
# Prenons un jeu d'entraînement X avec $n_x$ le nombre de variables et $m$ le nombre d'exemples.
#
# Imaginons que notre jeu de données est égale à $m$=50 000 000, l'entraînement de ce modèle est impossible. Pour rendre l'entraînement possible, nous allons entraîner plusieurs mini-batch $X^{\{i\}}$ afin d'entraîner tous nos exemples séquentiellement.
#
# Pour simuler ces mini-batch nous allons utiliser des générateurs qui vont fournir à l'algorithme les données par séquence.

# %%
# Nous allons créer de nouveau jeu de données contenant seulement les variables utilent à l'entraînement de notre modèle
train = data_train.loc[:, ('t1_norm', 'age')]

# Nous allons créer de nouveau jeu de données contenant seulement les variables utilent aux tests de notre modèle
test = data_test.loc[:, ('t1_norm', 'age')]

# On précise le nombre d'exemple que va contenir chaque batch
batch_size = 4

generator_train = generator_mri_regression(list_path=train, batch_size=batch_size, shuffle=True)

generator_test = generator_mri_regression(list_path=test, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ### La profondeur des architectures

# %% [markdown]
# #### Architecture de base

# %% [markdown]
# Dans un projet de machine learning nous allons toujours commencé par entraîner un modèle très simple pour voir à quel point problème est compris.
#
# Plus tard chaque amélioration pourra être comparé avec ce modèle dit "de base" afin de voir l'amélioration de ces performances.
#
# Comme vous pouvez le voir sur le schéma ci-dessous le modèle est composé de deux couches de convolution, une couche de maxpooling et une couche. Ensuite nous allons transformer nos matrices en vecteur c'est la partie "flatten" sur le schéma et pour finir nous aurons une couche complétement connectés.
#
# <img src="data/baseline1.png" >
#
# Ci-dessous vous pouvez voir l'implémentation en keras du schéma ci-dessus.

# %%
# Model
def base_model(size):
    """
    Model of "Predictiong brain age with deep learning from raw imaging data results in a reliable and heritable biomarker"

    Inputs:
        - model_options:
        - weights_path: path to where weights should be saved
    Output:
        - nets = list of NeuralNets (CNN1, CNN2)def Unet_3D_model(modalities, patch_size, filters=32, dropout_rate=0.2):

    """
    model = Sequential()
    model.add(Conv3D(filters=8,
                     kernel_size=(3, 3, 3),
                     activation='relu',
                     input_shape=size,
                     name="conv_1_1"))
    model.add(Conv3D(filters=8,
                     kernel_size=(3, 3, 3),
                     activation='relu',
                     name="conv_1_2"))
    model.add(MaxPooling3D(pool_size=(2, 2, 2),
                           strides=(2, 2, 2)))
    model.add(Flatten())
    model.add(Dense(units=1,
                    name="d_2"))
    return model

# %% [markdown]
# En utilisant la fonction "summary" nous avons le détail des paramètres qui compose notre modèle couche par couche.

# %%
model = base_model(SIZE)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1_1 (Conv3D)            (None, 191, 227, 191, 8)  224
# _________________________________________________________________
# conv_1_2 (Conv3D)            (None, 189, 225, 189, 8)  1736
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 94, 112, 94, 8)    0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 7917056)           0
# _________________________________________________________________
# d_2 (Dense)                  (None, 1)                 7917057
# =================================================================
# Total params: 7,919,017
# Trainable params: 7,919,017
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Dans ce partie nous initialisons nos "callbacks", ces fonctiosn servent à sauvegarder des informations tout au long de l'entraînement de nos données.

# %%
# Call back initialization
test_name = 'baseline_' + datetime.datetime.now().strftime("%Y-%m-%d_%H:%M:%S")

training_path = 'data/'+test_name
os.system('mkdir '+training_path)

hyperparameters = SaveHyperparameters(training_path, LEARNING_RATE, batch_size, 100, False, 0, 0, 'test_baseline')

save_metrics = SaveMetrics(training_path)

filepath="data/"+test_name+"/model_saved/"
os.system("mkdir "+filepath)

checkpoint = ModelCheckpoint(filepath+"HCP-test_weights-improvement-{epoch:02d}-{val_mean_absolute_error:.2f}.hdf5", monitor='val_mean_absolute_error', verbose=1, save_best_only=True, mode='min')

callbacks_list = [checkpoint, save_metrics]

# %% [markdown]
# Maintenant nous allons compilé notre modèle en spécifiant la fonction de coût que nous voulons utiliser pour entraîner notre modèle, la fonction d'optimisation que nous voulons utiliser pour mettre à jour nos paramètres et la métrique de performance qui sera calculer pour suivre l'évolution des performances tout au long de notre entraînement.

# %%
# Model initialization
model.compile(loss=['mae'],
              optimizer=SGD(lr=LEARNING_RATE),
              metrics=['mae'])

# %% [markdown]
# Maintenant, notre modèle est prêt pour l'entraînement.
#
# Nous donnons le générateur d'entraînement, le générateur de test, et le nombre d'itérations d'entraînement.

# %%
model.fit_generator(generator=generator_train.loader(),
                    steps_per_epoch=generator_train.get_len(),
                    epochs=5, 
                    verbose=1,
                    validation_data=generator_test.loader(),
                    validation_steps=generator_test.get_len(),
                    validation_freq=1,
                    shuffle=True,
                    initial_epoch=0,
                    callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 27/28 [===========================>..] - ETA: 1s - loss: 45.1336 - mean_absolute_error: 45.1336
# Epoch 00001: val_mean_absolute_error improved from inf to 44.43337, saving model to data/baseline_2020-02-28_17:10:59/model_saved/HCP-test_weights-improvement-01-44.43.hdf5
# 28/28 [==============================] - 83s 3s/step - loss: 44.5463 - mean_absolute_error: 44.8295 - val_loss: 44.5311 - val_mean_absolute_error: 44.4334
# Epoch 2/100
#  7/28 [======>.......................] - ETA: 15s - loss: 43.9380 - mean_absolute_error: 43.9380
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-769fa1393f7d> in <module>
#       8                     shuffle=True,
#       9                     initial_epoch=0,
# ---> 10                     callbacks=callbacks_list)
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1431         shuffle=shuffle,
#    1432         initial_epoch=initial_epoch,
# -> 1433         steps_name='steps_per_epoch')
#    1434
#    1435   def evaluate_generator(self,
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     262
#     263       is_deferred = not model._is_compiled
# --> 264       batch_outs = batch_function(*batch_data)
#     265       if not isinstance(batch_outs, list):
#     266         batch_outs = [batch_outs]
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1173       self._update_sample_weight_modes(sample_weights=sample_weights)
#    1174       self._make_train_function()
# -> 1175       outputs = self.train_function(ins)  # pylint: disable=not-callable
#    1176
#    1177     if reset_metrics:
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3290
#    3291     fetched = self._callable_fn(*array_vals,
# -> 3292                                 run_metadata=self.run_metadata)
#    3293     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3294     output_structure = nest.pack_sequence_as(
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# Votre modèle s'entraîne, cet entraînement peut être très long. Pendant l'entraînement nous allons sauvegarder automatiquement les modèles les plus performant et l'évolution des performances durant l'entraînement.
#
# Vous pouvez ci-dessous charger un modèle entraîner pendant 100 itérations avec le même jeu de données.

# %%
model.load_weights('data/models/model-baseline_it-100_data-100.hdf5')

# %% [markdown]
# Avec les données sauvegarder on peut visualiser l'évolution des performances au cours de l'entraînement.

# %%
data_training_base = pd.read_csv("data/training_data/metrics_baseline_100_100.csv")
plt.plot(data_training_base.loc[1:, 'epoch'], data_training_base.loc[1:, 'train_loss'], label='Training Mean Absolute Error')
plt.plot(data_training_base.loc[0:, 'epoch'], data_training_base.loc[0:, 'val_loss'], label='Validation Mean Absolute Error', color='green')
plt.legend(loc='upper right')
plt.title('Evolution of the error during the training using raw data')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error (age)')
plt.show()

# %% [markdown]
# On peut voir d'après le graphique ci-dessus que notre modèle souffre de sous-entraînement. Notre modèle n'est pas assez complexe pour comprendre le phénomène à modéliser.

# %% [markdown]
# #### Modèle intermédiaire
#
# Nous allons donc utiliser un modèle plus complexe afin de voir s'il arrive à mieux comprendre les phénomènes à utiliser. Vous pouvez voir le schéma de notre nouveau modèle ci-dessous.
#
# <img src="data/V2_model.png" >

# %%
# Model
def model_baseV2(size):
    """
    Model of "Predictiong brain age with deep learning from raw imaging data results in a reliable and heritable biomarker"

    Inputs:
        - model_options:
        - weights_path: path to where weights should be saved
    Output:
        - nets = list of NeuralNets (CNN1, CNN2)def Unet_3D_model(modalities, patch_size, filters=32, dropout_rate=0.2):

    """
    model = Sequential()
    model.add(Conv3D(filters=8,
                     kernel_size=(3, 3, 3),
                     activation='relu',
                     input_shape=size,
                     name="conv_1_1"))
    model.add(Conv3D(filters=8,
                     kernel_size=(3, 3, 3),
                     activation='relu',
                     name="conv_1_2"))
    model.add(MaxPooling3D(pool_size=(2, 2, 2),
                           strides=(2, 2, 2)))
    model.add(Conv3D(filters=16,
                     kernel_size=(3, 3, 3),
                     activation='relu',
                     input_shape=size,
                     name="conv_2_1"))
    model.add(Conv3D(filters=16,
                     kernel_size=(3, 3, 3),
                     activation='relu',
                     name="conv_2_2"))
    model.add(MaxPooling3D(pool_size=(2, 2, 2),
                           strides=(2, 2, 2)))
    model.add(Flatten())
    model.add(Dense(units=1,
                    name="d_2"))
    return model

# %%
model_V2 = model_baseV2(SIZE)
model_V2.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1_1 (Conv3D)            (None, 191, 227, 191, 8)  224
# _________________________________________________________________
# conv_1_2 (Conv3D)            (None, 189, 225, 189, 8)  1736
# _________________________________________________________________
# max_pooling3d_23 (MaxPooling (None, 94, 112, 94, 8)    0
# _________________________________________________________________
# conv_2_1 (Conv3D)            (None, 92, 110, 92, 16)   3472
# _________________________________________________________________
# conv_2_2 (Conv3D)            (None, 90, 108, 90, 16)   6928
# _________________________________________________________________
# max_pooling3d_24 (MaxPooling (None, 45, 54, 45, 16)    0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 1749600)           0
# _________________________________________________________________
# d_2 (Dense)                  (None, 1)                 1749601
# =================================================================
# Total params: 1,761,961
# Trainable params: 1,761,961
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Call back initialization
test_name = 'model_V2_' + datetime.datetime.now().strftime("%Y-%m-%d_%H:%M:%S")

training_path = 'data/'+test_name
os.system('mkdir '+training_path)

hyperparameters = SaveHyperparameters(training_path, LEARNING_RATE, batch_size, 100, False, 0, 0, 'test_baseline')

save_metrics = SaveMetrics(training_path)

filepath="data/"+test_name+"/model_saved/"
os.system("mkdir "+filepath)

checkpoint = ModelCheckpoint(filepath+"HCP-test_weights-improvement-{epoch:02d}-{val_mean_absolute_error:.2f}.hdf5", monitor='val_mean_absolute_error', verbose=1, save_best_only=True, mode='min')

callbacks_list = [checkpoint, save_metrics]

# %%
# Model initialization
model_V2.compile(loss=['mae'],
              optimizer=SGD(lr=LEARNING_RATE),
              metrics=['mae'])

# %%
model_V2.fit_generator(generator=generator_train.loader(),
                    steps_per_epoch=generator_train.get_len(),
                    epochs=5, 
                    verbose=1,
                    validation_data=generator_test.loader(),
                    validation_steps=generator_test.get_len(),
                    validation_freq=1,
                    shuffle=True,
                    initial_epoch=0,
                    callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 27/28 [===========================>..] - ETA: 0s - loss: 18.3198 - mean_absolute_error: 18.5658
# Epoch 00001: val_mean_absolute_error improved from inf to 16.52946, saving model to data/model_V2_2020-02-28_17:20:10/model_saved/HCP-test_weights-improvement-01-16.53.hdf5
# 28/28 [==============================] - 44s 2s/step - loss: 18.2521 - mean_absolute_error: 18.4797 - val_loss: 16.4281 - val_mean_absolute_error: 16.5295
# Epoch 2/100
#  7/28 [======>.......................] - ETA: 18s - loss: 16.0345 - mean_absolute_error: 16.0345
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-1b168fc51c37> in <module>
#       8                     shuffle=True,
#       9                     initial_epoch=0,
# ---> 10                     callbacks=callbacks_list)
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1431         shuffle=shuffle,
#    1432         initial_epoch=initial_epoch,
# -> 1433         steps_name='steps_per_epoch')
#    1434
#    1435   def evaluate_generator(self,
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     262
#     263       is_deferred = not model._is_compiled
# --> 264       batch_outs = batch_function(*batch_data)
#     265       if not isinstance(batch_outs, list):
#     266         batch_outs = [batch_outs]
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1173       self._update_sample_weight_modes(sample_weights=sample_weights)
#    1174       self._make_train_function()
# -> 1175       outputs = self.train_function(ins)  # pylint: disable=not-callable
#    1176
#    1177     if reset_metrics:
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3290
#    3291     fetched = self._callable_fn(*array_vals,
# -> 3292                                 run_metadata=self.run_metadata)
#    3293     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3294     output_structure = nest.pack_sequence_as(
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# Votre modèle s'entraîne, cet entraînement peut être très long. Pendant l'entraînement nous allons sauvegarder automatiquement les modèles les plus performant et l'évolution des performances durant l'entraînement.
#
# Vous pouvez ci-dessous charger un modèle entraîner pendant 100 itérations avec le même jeu de données.

# %%
model_V2.load_weights('data/models/model-v2_it-100_data-100.hdf5')

# %% [markdown]
# Avec les données sauvegarder on peut visualiser l'évolution des performances au cours de l'entraînement.

# %%
data_training_V2 = pd.read_csv("data/training_data/metrics_v2_100_100.csv")
plt.plot(data_training_V2.loc[:, 'epoch'], data_training_V2.loc[:, 'train_loss'], label='Training Mean Absolute Error')
plt.plot(data_training_V2.loc[:, 'epoch'], data_training_V2.loc[:, 'val_loss'], label='Validation Mean Absolute Error', color='green')
plt.legend(loc='upper right')
plt.title('Evolution of the error during the training using raw data')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error (age)')
plt.show()

# %% [markdown]
# On peut voir d'après le graphique ci-dessus que notre modèle comprend mieux notre phénomène que le modèle précédent. Nous allons voir ci prendre un modèle plus complexe nous donnera plus de performance.

# %% [markdown]
# #### Architecture plus élaboré
#
# Ce modèle est plus performant que le précédent en ayant 5 blocks au lieu de 2 précédemment (voir le schéma ci-dessous).
#
# <img src="data/cole_model1.png" >

# %%
# block of Cole model
def block_model_Cole(model, nb_block):
    model.add(Conv3D(filters=8*pow(2,nb_block),
                     kernel_size=(3, 3, 3),
                     padding='same',
                     activation='relu',
                     name="conv_"+str(nb_block+1)+"_1"))
    model.add(Conv3D(filters=8*pow(2,nb_block),
                     kernel_size=(3, 3, 3),
                     padding='same',
                     activation=None,
                     name="conv_"+str(nb_block+1)+"_2"))
    model.add(BatchNormalization(name="bn_"+str(nb_block+1)+"_3", axis=1))
    model.add(ReLU(name="relu_conv_"+str(nb_block+1)+"_4"))
    model.add(MaxPooling3D(pool_size=(2, 2, 2),
                           strides=(2, 2, 2)))
    return model

# Model
def cole_model(size):
    """
    Model of "Predictiong brain age with deep learning from raw imaging data results in a reliable and heritable biomarker"

    Inputs:
        - model_options:
        - weights_path: path to where weights should be saved
    Output:
        - nets = list of NeuralNets (CNN1, CNN2)def Unet_3D_model(modalities, patch_size, filters=32, dropout_rate=0.2):

    """
    model = Sequential()
    model.add(Conv3D(filters=8,
                     kernel_size=(3, 3, 3),
                     padding='same',
                     activation='relu',
                     input_shape=size,
                     name="conv_1_1"))
    model.add(Conv3D(filters=8,
                     kernel_size=(3, 3, 3),
                     padding='same',
                     activation=None,
                     name="conv_1_2"))
    model.add(BatchNormalization(name='bn_1_3', axis=1))
    model.add(ReLU(name='relu_conv_1_4'))
    model.add(MaxPooling3D(pool_size=(2, 2, 2),
                           strides=(2, 2, 2)))
    model = block_model_Cole(model, 1)
    model = block_model_Cole(model, 2)
    model = block_model_Cole(model, 3)
    model = block_model_Cole(model, 4)
    
    model.add(Flatten())
    model.add(Dense(units=1,
                    name="d_6"))
    return model

# %%
model_cole =  cole_model(SIZE)
model_cole.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1_1 (Conv3D)            (None, 193, 229, 193, 8)  224
# _________________________________________________________________
# conv_1_2 (Conv3D)            (None, 193, 229, 193, 8)  1736
# _________________________________________________________________
# bn_1_3 (BatchNormalization)  (None, 193, 229, 193, 8)  772
# _________________________________________________________________
# relu_conv_1_4 (ReLU)         (None, 193, 229, 193, 8)  0
# _________________________________________________________________
# max_pooling3d_16 (MaxPooling (None, 96, 114, 96, 8)    0
# _________________________________________________________________
# conv_2_1 (Conv3D)            (None, 96, 114, 96, 16)   3472
# _________________________________________________________________
# conv_2_2 (Conv3D)            (None, 96, 114, 96, 16)   6928
# _________________________________________________________________
# bn_2_3 (BatchNormalization)  (None, 96, 114, 96, 16)   384
# _________________________________________________________________
# relu_conv_2_4 (ReLU)         (None, 96, 114, 96, 16)   0
# _________________________________________________________________
# max_pooling3d_17 (MaxPooling (None, 48, 57, 48, 16)    0
# _________________________________________________________________
# conv_3_1 (Conv3D)            (None, 48, 57, 48, 32)    13856
# _________________________________________________________________
# conv_3_2 (Conv3D)            (None, 48, 57, 48, 32)    27680
# _________________________________________________________________
# bn_3_3 (BatchNormalization)  (None, 48, 57, 48, 32)    192
# _________________________________________________________________
# relu_conv_3_4 (ReLU)         (None, 48, 57, 48, 32)    0
# _________________________________________________________________
# max_pooling3d_18 (MaxPooling (None, 24, 28, 24, 32)    0
# _________________________________________________________________
# conv_4_1 (Conv3D)            (None, 24, 28, 24, 64)    55360
# _________________________________________________________________
# conv_4_2 (Conv3D)            (None, 24, 28, 24, 64)    110656
# _________________________________________________________________
# bn_4_3 (BatchNormalization)  (None, 24, 28, 24, 64)    96
# _________________________________________________________________
# relu_conv_4_4 (ReLU)         (None, 24, 28, 24, 64)    0
# _________________________________________________________________
# max_pooling3d_19 (MaxPooling (None, 12, 14, 12, 64)    0
# _________________________________________________________________
# conv_5_1 (Conv3D)            (None, 12, 14, 12, 128)   221312
# _________________________________________________________________
# conv_5_2 (Conv3D)            (None, 12, 14, 12, 128)   442496
# _________________________________________________________________
# bn_5_3 (BatchNormalization)  (None, 12, 14, 12, 128)   48
# _________________________________________________________________
# relu_conv_5_4 (ReLU)         (None, 12, 14, 12, 128)   0
# _________________________________________________________________
# max_pooling3d_20 (MaxPooling (None, 6, 7, 6, 128)      0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 32256)             0
# _________________________________________________________________
# d_6 (Dense)                  (None, 1)                 32257
# =================================================================
# Total params: 917,469
# Trainable params: 916,723
# Non-trainable params: 746
# _________________________________________________________________

# %%
# Model initialization
model_cole.compile(loss=['mae'],
              optimizer=SGD(lr=LEARNING_RATE),
              metrics=['mae'])

# %%
# Call back initialization
test_name = 'cole_' + datetime.datetime.now().strftime("%Y-%m-%d_%H:%M:%S")

training_path = 'data/'+test_name
os.system('mkdir '+training_path)

hyperparameters = SaveHyperparameters(training_path, LEARNING_RATE, batch_size, 100, False, 0, 0, 'test_baseline')

save_metrics = SaveMetrics(training_path)

filepath="data/"+test_name+"/model_saved/"
os.system("mkdir "+filepath)

checkpoint = ModelCheckpoint(filepath+"HCP-test_weights-improvement-{epoch:02d}-{val_mean_absolute_error:.2f}.hdf5", monitor='val_mean_absolute_error', verbose=1, save_best_only=True, mode='min')

callbacks_list = [checkpoint, save_metrics]

# %%
model_cole.fit_generator(generator=generator_train.loader(),
                    steps_per_epoch=generator_train.get_len(),
                    epochs=5, 
                    verbose=1,
                    validation_data=generator_test.loader(),
                    validation_steps=generator_test.get_len(),
                    validation_freq=1,
                    shuffle=True,
                    initial_epoch=0,
                    callbacks=callbacks_list)
# Out:
# Epoch 1/5
# 27/28 [===========================>..] - ETA: 1s - loss: 18.1410 - mean_absolute_error: 18.2070
# Epoch 00001: val_mean_absolute_error improved from inf to 40.91560, saving model to data/cole_2020-02-28_17:27:44/model_saved/HCP-test_weights-improvement-01-40.92.hdf5
# 28/28 [==============================] - 75s 3s/step - loss: 17.9043 - mean_absolute_error: 17.9615 - val_loss: 40.8937 - val_mean_absolute_error: 40.9156
# Epoch 2/5
# 27/28 [===========================>..] - ETA: 0s - loss: 16.1486 - mean_absolute_error: 16.1154
# Epoch 00002: val_mean_absolute_error improved from 40.91560 to 33.74170, saving model to data/cole_2020-02-28_17:27:44/model_saved/HCP-test_weights-improvement-02-33.74.hdf5
# 28/28 [==============================] - 47s 2s/step - loss: 16.3295 - mean_absolute_error: 16.3018 - val_loss: 33.3938 - val_mean_absolute_error: 33.7417
# Epoch 3/5
# 27/28 [===========================>..] - ETA: 0s - loss: 16.1523 - mean_absolute_error: 16.3268
# Epoch 00003: val_mean_absolute_error improved from 33.74170 to 16.68040, saving model to data/cole_2020-02-28_17:27:44/model_saved/HCP-test_weights-improvement-03-16.68.hdf5
# 28/28 [==============================] - 46s 2s/step - loss: 16.2511 - mean_absolute_error: 16.4150 - val_loss: 16.8081 - val_mean_absolute_error: 16.6804
# Epoch 4/5
# 27/28 [===========================>..] - ETA: 0s - loss: 15.7435 - mean_absolute_error: 15.6703
# Epoch 00004: val_mean_absolute_error did not improve from 16.68040
# 28/28 [==============================] - 46s 2s/step - loss: 15.7366 - mean_absolute_error: 15.6684 - val_loss: 27.6677 - val_mean_absolute_error: 28.0540
# Epoch 5/5
# 27/28 [===========================>..] - ETA: 0s - loss: 15.1054 - mean_absolute_error: 14.8979
# Epoch 00005: val_mean_absolute_error did not improve from 16.68040
# 28/28 [==============================] - 46s 2s/step - loss: 15.2028 - mean_absolute_error: 15.0115 - val_loss: 22.5596 - val_mean_absolute_error: 22.9137

# %% [markdown]
# Votre modèle s'entraîne, cet entraînement peut être très long. Pendant l'entraînement nous allons sauvegarder automatiquement les modèles les plus performant et l'évolution des performances durant l'entraînement.
#
# Vous pouvez ci-dessous charger un modèle entraîner pendant 100 itérations avec le même jeu de données.

# %%
model_cole.load_weights('data/models/model-cole_it-100_data-100.hdf5')

# %% [markdown]
# Avec les données sauvegarder on peut visualiser l'évolution des performances au cours de l'entraînement.

# %%
data_training_cole = pd.read_csv("data/training_data/metrics_cole_100_100.csv")
plt.plot(data_training_cole.loc[:, 'epoch'], data_training_cole.loc[:, 'train_loss'], label='Training Mean Absolute Error')
plt.plot(data_training_cole.loc[:, 'epoch'], data_training_cole.loc[:, 'val_loss'], label='Validation Mean Absolute Error', color='green')
plt.legend(loc='upper right')
plt.title('Evolution of the error during the training using raw data')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error (age)')
plt.show()

# %% [markdown]
# On peut voir que le modèle donne des performances du même ordre de grandeur que le modèle précédent. Complexifier le modèle davantage ne le rendra pas plus performant.

# %% [markdown]
# #### Etude des résultats

# %% [markdown]
# On va tracer l'évolution des performances de nos modèles en fonction du modèle.

# %%
plt.plot(data_training_base.loc[:, 'epoch'], data_training_base.loc[:, 'val_loss'], label='Validation Mean Absolute Error base model', color='blue')
plt.plot(data_training_V2.loc[:, 'epoch'], data_training_V2.loc[:, 'val_loss'], label='Validation Mean Absolute Error V2 model', color='green')
plt.plot(data_training_cole.loc[:, 'epoch'], data_training_cole.loc[:, 'val_loss'], label='Validation Mean Absolute Error Cole model', color='red')
plt.legend(loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)
plt.title('Evolution of the error during the training using raw data')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error (age)')
plt.show()

# %% [markdown]
# On peut déduire que la première architecture n'est pas assez complexe pour résoudre notre problème. La deuxième architecture comprend mieux le problème. Un modèle plus complexe ne comprend pas mieux le problème.
#
# Il faudrait surement ajouter des données afin que notre algorithme puisse s'entraîner davantage.

# %% [markdown]
# ### Le nombre de données

# %% [markdown]
# Chargement d'un jeu de données de 500 sujets sain.

# %%
data_frame = pd.read_csv("data/IXI.csv")

# Nous allons créer de nouveau jeu de données contenant seulement les variables utilent à l'entraînement de notre modèle
data = data_frame.loc[:, ('t1_norm', 'age')]

train_matrix, test_matrix, val_matrix = train_test_val(data)

# On précise le nombre d'exemple que va contenir chaque batch
batch_size = 4

generator_train = generator_mri_regression(list_path=train_matrix, batch_size=batch_size, shuffle=True)

generator_test = generator_mri_regression(list_path=test_matrix, batch_size=batch_size, shuffle=True)

# %% [markdown]
# #### Architecture intermédiaire

# %%
model_V2 = model_baseV2(SIZE)
model_V2.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1_1 (Conv3D)            (None, 191, 227, 191, 8)  224
# _________________________________________________________________
# conv_1_2 (Conv3D)            (None, 189, 225, 189, 8)  1736
# _________________________________________________________________
# max_pooling3d_25 (MaxPooling (None, 94, 112, 94, 8)    0
# _________________________________________________________________
# conv_2_1 (Conv3D)            (None, 92, 110, 92, 16)   3472
# _________________________________________________________________
# conv_2_2 (Conv3D)            (None, 90, 108, 90, 16)   6928
# _________________________________________________________________
# max_pooling3d_26 (MaxPooling (None, 45, 54, 45, 16)    0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 1749600)           0
# _________________________________________________________________
# d_2 (Dense)                  (None, 1)                 1749601
# =================================================================
# Total params: 1,761,961
# Trainable params: 1,761,961
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Call back initialization
test_name = 'model_V2_ixitrain_' + datetime.datetime.now().strftime("%Y-%m-%d_%H:%M:%S")

training_path = 'data/'+test_name
os.system('mkdir '+training_path)

hyperparameters = SaveHyperparameters(training_path, LEARNING_RATE, batch_size, 100, False, 0, 0, 'test_baseline')

save_metrics = SaveMetrics(training_path)

filepath="data/"+test_name+"/model_saved/"
os.system("mkdir "+filepath)

checkpoint = ModelCheckpoint(filepath+"HCP-test_weights-improvement-{epoch:02d}-{val_mean_absolute_error:.2f}.hdf5", monitor='val_mean_absolute_error', verbose=1, save_best_only=True, mode='min')

callbacks_list = [checkpoint, save_metrics]

# %%
# Model initialization
model_V2.compile(loss=['mae'],
              optimizer=SGD(lr=LEARNING_RATE),
              metrics=['mae'])

# %%
model_V2.fit_generator(generator=generator_train.loader(),
                    steps_per_epoch=generator_train.get_len(),
                    epochs=5, 
                    verbose=1,
                    validation_data=generator_test.loader(),
                    validation_steps=generator_test.get_len(),
                    validation_freq=1,
                    shuffle=True,
                    initial_epoch=0,
                    callbacks=callbacks_list)
# Out:
# Epoch 1/5
# 85/86 [============================>.] - ETA: 0s - loss: 23.9752 - mean_absolute_error: 24.1215
# Epoch 00001: val_mean_absolute_error improved from inf to 21.42395, saving model to data/model_V2_ixitrain_2020-02-28_17:44:37/model_saved/HCP-test_weights-improvement-01-21.42.hdf5
# 86/86 [==============================] - 99s 1s/step - loss: 24.0173 - mean_absolute_error: 24.1605 - val_loss: 21.9316 - val_mean_absolute_error: 21.4240
# Epoch 2/5
# 85/86 [============================>.] - ETA: 0s - loss: 17.9983 - mean_absolute_error: 17.6828
# Epoch 00002: val_mean_absolute_error improved from 21.42395 to 14.00037, saving model to data/model_V2_ixitrain_2020-02-28_17:44:37/model_saved/HCP-test_weights-improvement-02-14.00.hdf5
# 86/86 [==============================] - 97s 1s/step - loss: 17.9997 - mean_absolute_error: 17.6916 - val_loss: 13.8448 - val_mean_absolute_error: 14.0004
# Epoch 3/5
# 19/86 [=====>........................] - ETA: 59s - loss: 19.2263 - mean_absolute_error: 19.2263
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-110-6224d2b01487> in <module>
#       8                     shuffle=True,
#       9                     initial_epoch=0,
# ---> 10                     callbacks=callbacks_list)
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1431         shuffle=shuffle,
#    1432         initial_epoch=initial_epoch,
# -> 1433         steps_name='steps_per_epoch')
#    1434
#    1435   def evaluate_generator(self,
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     262
#     263       is_deferred = not model._is_compiled
# --> 264       batch_outs = batch_function(*batch_data)
#     265       if not isinstance(batch_outs, list):
#     266         batch_outs = [batch_outs]
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1173       self._update_sample_weight_modes(sample_weights=sample_weights)
#    1174       self._make_train_function()
# -> 1175       outputs = self.train_function(ins)  # pylint: disable=not-callable
#    1176
#    1177     if reset_metrics:
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3290
#    3291     fetched = self._callable_fn(*array_vals,
# -> 3292                                 run_metadata=self.run_metadata)
#    3293     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3294     output_structure = nest.pack_sequence_as(
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# Votre modèle s'entraîne, cet entraînement peut être très long. Pendant l'entraînement nous allons sauvegarder automatiquement les modèles les plus performant et l'évolution des performances durant l'entraînement.
#
# Vous pouvez ci-dessous charger un modèle entraîner pendant 100 itérations avec le même jeu de données.

# %%
model_V2.load_weights('data/models/model-v2_it-100_data-500.hdf5')

# %% [markdown]
# Avec les données sauvegarder on peut visualiser l'évolution des performances au cours de l'entraînement.

# %%
data_training_V2 = pd.read_csv("data/training_data/metrics_v2_100_500.csv")
plt.plot(data_training_V2.loc[1:, 'epoch'], data_training_V2.loc[1:, 'train_loss'], label='Training Mean Absolute Error')
plt.plot(data_training_V2.loc[0:, 'epoch'], data_training_V2.loc[0:, 'val_loss'], label='Validation Mean Absolute Error', color='green')
plt.legend(loc='upper right')
plt.title('Evolution of the error during the training using raw data')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error (age)')
plt.show()

# %% [markdown]
# L'ajout de données a permi de résoudre notre problème plus précisément.

# %% [markdown]
# #### Architecture plus élaborée

# %%
model_cole =  cole_model(SIZE)
model_cole.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1_1 (Conv3D)            (None, 193, 229, 193, 8)  224
# _________________________________________________________________
# conv_1_2 (Conv3D)            (None, 193, 229, 193, 8)  1736
# _________________________________________________________________
# bn_1_3 (BatchNormalization)  (None, 193, 229, 193, 8)  772
# _________________________________________________________________
# relu_conv_1_4 (ReLU)         (None, 193, 229, 193, 8)  0
# _________________________________________________________________
# max_pooling3d_32 (MaxPooling (None, 96, 114, 96, 8)    0
# _________________________________________________________________
# conv_2_1 (Conv3D)            (None, 96, 114, 96, 16)   3472
# _________________________________________________________________
# conv_2_2 (Conv3D)            (None, 96, 114, 96, 16)   6928
# _________________________________________________________________
# bn_2_3 (BatchNormalization)  (None, 96, 114, 96, 16)   384
# _________________________________________________________________
# relu_conv_2_4 (ReLU)         (None, 96, 114, 96, 16)   0
# _________________________________________________________________
# max_pooling3d_33 (MaxPooling (None, 48, 57, 48, 16)    0
# _________________________________________________________________
# conv_3_1 (Conv3D)            (None, 48, 57, 48, 32)    13856
# _________________________________________________________________
# conv_3_2 (Conv3D)            (None, 48, 57, 48, 32)    27680
# _________________________________________________________________
# bn_3_3 (BatchNormalization)  (None, 48, 57, 48, 32)    192
# _________________________________________________________________
# relu_conv_3_4 (ReLU)         (None, 48, 57, 48, 32)    0
# _________________________________________________________________
# max_pooling3d_34 (MaxPooling (None, 24, 28, 24, 32)    0
# _________________________________________________________________
# conv_4_1 (Conv3D)            (None, 24, 28, 24, 64)    55360
# _________________________________________________________________
# conv_4_2 (Conv3D)            (None, 24, 28, 24, 64)    110656
# _________________________________________________________________
# bn_4_3 (BatchNormalization)  (None, 24, 28, 24, 64)    96
# _________________________________________________________________
# relu_conv_4_4 (ReLU)         (None, 24, 28, 24, 64)    0
# _________________________________________________________________
# max_pooling3d_35 (MaxPooling (None, 12, 14, 12, 64)    0
# _________________________________________________________________
# conv_5_1 (Conv3D)            (None, 12, 14, 12, 128)   221312
# _________________________________________________________________
# conv_5_2 (Conv3D)            (None, 12, 14, 12, 128)   442496
# _________________________________________________________________
# bn_5_3 (BatchNormalization)  (None, 12, 14, 12, 128)   48
# _________________________________________________________________
# relu_conv_5_4 (ReLU)         (None, 12, 14, 12, 128)   0
# _________________________________________________________________
# max_pooling3d_36 (MaxPooling (None, 6, 7, 6, 128)      0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 32256)             0
# _________________________________________________________________
# d_6 (Dense)                  (None, 1)                 32257
# =================================================================
# Total params: 917,469
# Trainable params: 916,723
# Non-trainable params: 746
# _________________________________________________________________

# %%
# Model initialization
model_cole.compile(loss=['mae'],
              optimizer=SGD(lr=LEARNING_RATE),
              metrics=['mae'])

# %%
# Call back initialization
test_name = 'cole_ixi_train_' + datetime.datetime.now().strftime("%Y-%m-%d_%H:%M:%S")

training_path = 'data/'+test_name
os.system('mkdir '+training_path)

hyperparameters = SaveHyperparameters(training_path, LEARNING_RATE, batch_size, 100, False, 0, 0, 'test_baseline')

save_metrics = SaveMetrics(training_path)

filepath="data/"+test_name+"/model_saved/"
os.system("mkdir "+filepath)

checkpoint = ModelCheckpoint(filepath+"HCP-test_weights-improvement-{epoch:02d}-{val_mean_absolute_error:.2f}.hdf5", monitor='val_mean_absolute_error', verbose=1, save_best_only=True, mode='min')

callbacks_list = [checkpoint, save_metrics]

# %%
model_cole.fit_generator(generator=generator_train.loader(),
                    steps_per_epoch=generator_train.get_len(),
                    epochs=5, 
                    verbose=1,
                    validation_data=generator_test.loader(),
                    validation_steps=generator_test.get_len(),
                    validation_freq=1,
                    shuffle=True,
                    initial_epoch=0,
                    callbacks=callbacks_list)
# Out:
# Epoch 1/5
# 85/86 [============================>.] - ETA: 1s - loss: 16.6402 - mean_absolute_error: 16.7684
# Epoch 00001: val_mean_absolute_error improved from inf to 27.44907, saving model to data/cole_ixi_train_2020-02-28_17:51:13/model_saved/HCP-test_weights-improvement-01-27.45.hdf5
# 86/86 [==============================] - 118s 1s/step - loss: 16.5741 - mean_absolute_error: 16.6988 - val_loss: 27.4362 - val_mean_absolute_error: 27.4491
# Epoch 2/5
# 85/86 [============================>.] - ETA: 0s - loss: 15.3302 - mean_absolute_error: 15.2894
# Epoch 00002: val_mean_absolute_error improved from 27.44907 to 14.40317, saving model to data/cole_ixi_train_2020-02-28_17:51:13/model_saved/HCP-test_weights-improvement-02-14.40.hdf5
# 86/86 [==============================] - 101s 1s/step - loss: 15.3542 - mean_absolute_error: 15.3146 - val_loss: 14.1813 - val_mean_absolute_error: 14.4032
# Epoch 3/5
# 85/86 [============================>.] - ETA: 0s - loss: 12.4831 - mean_absolute_error: 12.4306
# Epoch 00003: val_mean_absolute_error did not improve from 14.40317
# 86/86 [==============================] - 101s 1s/step - loss: 12.6078 - mean_absolute_error: 12.5576 - val_loss: 21.3968 - val_mean_absolute_error: 21.4224
# Epoch 4/5
# 85/86 [============================>.] - ETA: 0s - loss: 15.1136 - mean_absolute_error: 14.9694
# Epoch 00004: val_mean_absolute_error improved from 14.40317 to 13.84541, saving model to data/cole_ixi_train_2020-02-28_17:51:13/model_saved/HCP-test_weights-improvement-04-13.85.hdf5
# 86/86 [==============================] - 101s 1s/step - loss: 15.1901 - mean_absolute_error: 15.0498 - val_loss: 13.8634 - val_mean_absolute_error: 13.8454
# Epoch 5/5
# 85/86 [============================>.] - ETA: 0s - loss: 14.8429 - mean_absolute_error: 14.9260
# Epoch 00005: val_mean_absolute_error did not improve from 13.84541
# 86/86 [==============================] - 101s 1s/step - loss: 14.8871 - mean_absolute_error: 14.9686 - val_loss: 15.3983 - val_mean_absolute_error: 15.1607

# %% [markdown]
# Votre modèle s'entraîne, cet entraînement peut être très long. Pendant l'entraînement nous allons sauvegarder automatiquement les modèles les plus performant et l'évolution des performances durant l'entraînement.
#
# Vous pouvez ci-dessous charger un modèle entraîner pendant 100 itérations avec le même jeu de données.

# %%
model_cole.load_weights('data/models/model-cole_it-100_data-500.hdf5')

# %% [markdown]
# Avec les données sauvegarder on peut visualiser l'évolution des performances au cours de l'entraînement.

# %%
data_training_cole = pd.read_csv("data/training_data/metrics_cole_100_500.csv")
plt.plot(data_training_cole.loc[1:, 'epoch'], data_training_cole.loc[1:, 'train_loss'], label='Training Mean Absolute Error')
plt.plot(data_training_cole.loc[0:, 'epoch'], data_training_cole.loc[0:, 'val_loss'], label='Validation Mean Absolute Error', color='green')
plt.legend(loc='upper right')
plt.title('Evolution of the error during the training using raw data')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error (age)')
plt.show()

# %% [markdown]
# L'ajout de données a permi de résoudre notre problème plus précisément.

# %% [markdown]
# #### Etude des résultats
#
# On va tracer l'évolution des performances de nos modèles en fonction du modèle.

# %%
plt.plot(data_training_V2.loc[:, 'epoch'], data_training_V2.loc[:, 'val_loss'], label='Validation Mean Absolute Error V2 model', color='green')
plt.plot(data_training_cole.loc[:, 'epoch'], data_training_cole.loc[:, 'val_loss'], label='Validation Mean Absolute Error Cole model', color='red')
plt.legend(loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)
plt.title('Evolution of the error during the training using raw data')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error (age)')
plt.show()

# %% [markdown]
# On voit que nos modèles ont des performances similaire. Mais un modèle plus complexe met en générale plus de temps pour s'entraîner qu'un modèle plus simple.

# %% [markdown]
# ### Nombre d'itérations
#
# Nous allons étudier si augmenter le nombre d'itérations va augmenter la performance du modèle le plus complexe par rapport au modèle plus simple.

# %% [markdown]
# #### Modèle intermédiaire

# %%
model_V2 = model_baseV2(SIZE)
model_V2.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1_1 (Conv3D)            (None, 191, 227, 191, 8)  224
# _________________________________________________________________
# conv_1_2 (Conv3D)            (None, 189, 225, 189, 8)  1736
# _________________________________________________________________
# max_pooling3d_37 (MaxPooling (None, 94, 112, 94, 8)    0
# _________________________________________________________________
# conv_2_1 (Conv3D)            (None, 92, 110, 92, 16)   3472
# _________________________________________________________________
# conv_2_2 (Conv3D)            (None, 90, 108, 90, 16)   6928
# _________________________________________________________________
# max_pooling3d_38 (MaxPooling (None, 45, 54, 45, 16)    0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 1749600)           0
# _________________________________________________________________
# d_2 (Dense)                  (None, 1)                 1749601
# =================================================================
# Total params: 1,761,961
# Trainable params: 1,761,961
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Call back initialization
test_name = 'it300_model_V2_ixitrain_' + datetime.datetime.now().strftime("%Y-%m-%d_%H:%M:%S")

training_path = 'data/'+test_name
os.system('mkdir '+training_path)

hyperparameters = SaveHyperparameters(training_path, LEARNING_RATE, batch_size, 100, False, 0, 0, 'test_baseline')

save_metrics = SaveMetrics(training_path)

filepath="data/"+test_name+"/model_saved/"
os.system("mkdir "+filepath)

checkpoint = ModelCheckpoint(filepath+"HCP-test_weights-improvement-{epoch:02d}-{val_mean_absolute_error:.2f}.hdf5", monitor='val_mean_absolute_error', verbose=1, save_best_only=True, mode='min')

callbacks_list = [checkpoint, save_metrics]

# %%
# Model initialization
model_V2.compile(loss=['mae'],
              optimizer=SGD(lr=LEARNING_RATE),
              metrics=['mae'])

# %%
model_V2.fit_generator(generator=generator_train.loader(),
                    steps_per_epoch=generator_train.get_len(),
                    epochs=5, 
                    verbose=1,
                    validation_data=generator_test.loader(),
                    validation_steps=generator_test.get_len(),
                    validation_freq=1,
                    shuffle=True,
                    initial_epoch=0,
                    callbacks=callbacks_list)
# Out:
# Epoch 1/5
# 77/86 [=========================>....] - ETA: 8s - loss: 30.9570 - mean_absolute_error: 31.0007
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-138-6224d2b01487> in <module>
#       8                     shuffle=True,
#       9                     initial_epoch=0,
# ---> 10                     callbacks=callbacks_list)
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1431         shuffle=shuffle,
#    1432         initial_epoch=initial_epoch,
# -> 1433         steps_name='steps_per_epoch')
#    1434
#    1435   def evaluate_generator(self,
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     262
#     263       is_deferred = not model._is_compiled
# --> 264       batch_outs = batch_function(*batch_data)
#     265       if not isinstance(batch_outs, list):
#     266         batch_outs = [batch_outs]
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1173       self._update_sample_weight_modes(sample_weights=sample_weights)
#    1174       self._make_train_function()
# -> 1175       outputs = self.train_function(ins)  # pylint: disable=not-callable
#    1176
#    1177     if reset_metrics:
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3290
#    3291     fetched = self._callable_fn(*array_vals,
# -> 3292                                 run_metadata=self.run_metadata)
#    3293     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3294     output_structure = nest.pack_sequence_as(
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# Votre modèle s'entraîne, cet entraînement peut être très long. Pendant l'entraînement nous allons sauvegarder automatiquement les modèles les plus performant et l'évolution des performances durant l'entraînement.
#
# Vous pouvez ci-dessous charger un modèle entraîner pendant 500 itérations avec le même jeu de données.

# %%
model_V2.load_weights('data/models/model-v2_it-300_data-500.hdf5')

# %% [markdown]
# Avec les données sauvegarder on peut visualiser l'évolution des performances au cours de l'entraînement.

# %%
data_training_V2 = pd.read_csv("data/training_data/metrics_v2_it-300_data-500.csv")
plt.plot(data_training_V2.loc[1:, 'epoch'], data_training_V2.loc[1:, 'train_loss'], label='Training Mean Absolute Error')
plt.plot(data_training_V2.loc[0:, 'epoch'], data_training_V2.loc[0:, 'val_loss'], label='Validation Mean Absolute Error', color='green')
plt.legend(loc='upper right')
plt.title('Evolution of the error during the training using raw data')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error (age)')
plt.show()

# %% [markdown]
# On voit que l'augmentation de l'itération augmente la performance sur le jeu d'entraînement sans toutefois augmenter la performance sur le jeu de test. C'est le signe du sur-entraînement de notre modèle.

# %% [markdown]
# #### Modèle plus élaboré

# %%
model_cole =  cole_model(SIZE)
model_cole.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1_1 (Conv3D)            (None, 193, 229, 193, 8)  224
# _________________________________________________________________
# conv_1_2 (Conv3D)            (None, 193, 229, 193, 8)  1736
# _________________________________________________________________
# bn_1_3 (BatchNormalization)  (None, 193, 229, 193, 8)  772
# _________________________________________________________________
# relu_conv_1_4 (ReLU)         (None, 193, 229, 193, 8)  0
# _________________________________________________________________
# max_pooling3d_39 (MaxPooling (None, 96, 114, 96, 8)    0
# _________________________________________________________________
# conv_2_1 (Conv3D)            (None, 96, 114, 96, 16)   3472
# _________________________________________________________________
# conv_2_2 (Conv3D)            (None, 96, 114, 96, 16)   6928
# _________________________________________________________________
# bn_2_3 (BatchNormalization)  (None, 96, 114, 96, 16)   384
# _________________________________________________________________
# relu_conv_2_4 (ReLU)         (None, 96, 114, 96, 16)   0
# _________________________________________________________________
# max_pooling3d_40 (MaxPooling (None, 48, 57, 48, 16)    0
# _________________________________________________________________
# conv_3_1 (Conv3D)            (None, 48, 57, 48, 32)    13856
# _________________________________________________________________
# conv_3_2 (Conv3D)            (None, 48, 57, 48, 32)    27680
# _________________________________________________________________
# bn_3_3 (BatchNormalization)  (None, 48, 57, 48, 32)    192
# _________________________________________________________________
# relu_conv_3_4 (ReLU)         (None, 48, 57, 48, 32)    0
# _________________________________________________________________
# max_pooling3d_41 (MaxPooling (None, 24, 28, 24, 32)    0
# _________________________________________________________________
# conv_4_1 (Conv3D)            (None, 24, 28, 24, 64)    55360
# _________________________________________________________________
# conv_4_2 (Conv3D)            (None, 24, 28, 24, 64)    110656
# _________________________________________________________________
# bn_4_3 (BatchNormalization)  (None, 24, 28, 24, 64)    96
# _________________________________________________________________
# relu_conv_4_4 (ReLU)         (None, 24, 28, 24, 64)    0
# _________________________________________________________________
# max_pooling3d_42 (MaxPooling (None, 12, 14, 12, 64)    0
# _________________________________________________________________
# conv_5_1 (Conv3D)            (None, 12, 14, 12, 128)   221312
# _________________________________________________________________
# conv_5_2 (Conv3D)            (None, 12, 14, 12, 128)   442496
# _________________________________________________________________
# bn_5_3 (BatchNormalization)  (None, 12, 14, 12, 128)   48
# _________________________________________________________________
# relu_conv_5_4 (ReLU)         (None, 12, 14, 12, 128)   0
# _________________________________________________________________
# max_pooling3d_43 (MaxPooling (None, 6, 7, 6, 128)      0
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 32256)             0
# _________________________________________________________________
# d_6 (Dense)                  (None, 1)                 32257
# =================================================================
# Total params: 917,469
# Trainable params: 916,723
# Non-trainable params: 746
# _________________________________________________________________

# %%
# Model initialization
model_cole.compile(loss=['mae'],
              optimizer=SGD(lr=LEARNING_RATE),
              metrics=['mae'])

# %%
# Call back initialization
test_name = 'it300_cole_ixi_train_' + datetime.datetime.now().strftime("%Y-%m-%d_%H:%M:%S")

training_path = 'data/'+test_name
os.system('mkdir '+training_path)

hyperparameters = SaveHyperparameters(training_path, LEARNING_RATE, batch_size, 100, False, 0, 0, 'test_baseline')

save_metrics = SaveMetrics(training_path)

filepath="data/"+test_name+"/model_saved/"
os.system("mkdir "+filepath)

checkpoint = ModelCheckpoint(filepath+"HCP-test_weights-improvement-{epoch:02d}-{val_mean_absolute_error:.2f}.hdf5", monitor='val_mean_absolute_error', verbose=1, save_best_only=True, mode='min')

callbacks_list = [checkpoint, save_metrics]

# %%
model_cole.fit_generator(generator=generator_train.loader(),
                    steps_per_epoch=generator_train.get_len(),
                    epochs=5, 
                    verbose=1,
                    validation_data=generator_test.loader(),
                    validation_steps=generator_test.get_len(),
                    validation_freq=1,
                    shuffle=True,
                    initial_epoch=0,
                    callbacks=callbacks_list)
# Out:
# Epoch 1/5
# 85/86 [============================>.] - ETA: 0s - loss: 16.5568 - mean_absolute_error: 16.6577
# Epoch 00001: val_mean_absolute_error improved from inf to 15.48631, saving model to data/it300_cole_ixi_train_2020-02-28_18:19:09/model_saved/HCP-test_weights-improvement-01-15.49.hdf5
# 86/86 [==============================] - 103s 1s/step - loss: 16.5938 - mean_absolute_error: 16.6928 - val_loss: 15.3153 - val_mean_absolute_error: 15.4863
# Epoch 2/5
# 20/86 [=====>........................] - ETA: 1:01 - loss: 16.6697 - mean_absolute_error: 16.7725
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-146-de06b9448a5e> in <module>
#       8                     shuffle=True,
#       9                     initial_epoch=0,
# ---> 10                     callbacks=callbacks_list)
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1431         shuffle=shuffle,
#    1432         initial_epoch=initial_epoch,
# -> 1433         steps_name='steps_per_epoch')
#    1434
#    1435   def evaluate_generator(self,
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     262
#     263       is_deferred = not model._is_compiled
# --> 264       batch_outs = batch_function(*batch_data)
#     265       if not isinstance(batch_outs, list):
#     266         batch_outs = [batch_outs]
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1173       self._update_sample_weight_modes(sample_weights=sample_weights)
#    1174       self._make_train_function()
# -> 1175       outputs = self.train_function(ins)  # pylint: disable=not-callable
#    1176
#    1177     if reset_metrics:
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3290
#    3291     fetched = self._callable_fn(*array_vals,
# -> 3292                                 run_metadata=self.run_metadata)
#    3293     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3294     output_structure = nest.pack_sequence_as(
#
# ~/.conda/envs/tensorflow-gpu/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# Votre modèle s'entraîne, cet entraînement peut être très long. Pendant l'entraînement nous allons sauvegarder automatiquement les modèles les plus performant et l'évolution des performances durant l'entraînement.
#
# Vous pouvez ci-dessous charger un modèle entraîner pendant 500 itérations avec le même jeu de données.

# %%
model_cole.load_weights('data/models/model-cole_it-300_-data.hdf5')

# %% [markdown]
# Avec les données sauvegarder on peut visualiser l'évolution des performances au cours de l'entraînement.

# %%
data_training_cole = pd.read_csv("data/training_data/metrics_cole_300_500.csv")
plt.plot(data_training_cole.loc[1:, 'epoch'], data_training_cole.loc[1:, 'train_loss'], label='Training Mean Absolute Error')
plt.plot(data_training_cole.loc[0:, 'epoch'], data_training_cole.loc[0:, 'val_loss'], label='Validation Mean Absolute Error', color='green')
plt.legend(loc='upper right')
plt.title('Evolution of the error during the training using raw data')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error (age)')
plt.show()

# %% [markdown]
# On voit que l'augmentation de l'itération augmente la performance sur le jeu d'entraînement sans toutefois augmenter la performance sur le jeu de test. C'est le signe du sur-entraînement de notre modèle.

# %% [markdown]
# #### Etude des résultats
#
# On va tracer l'évolution des performances de nos modèles en fonction du modèle.

# %%
plt.plot(data_training_V2.loc[:, 'epoch'], data_training_V2.loc[:, 'val_loss'], label='Validation Mean Absolute Error V2 model', color='green')
plt.plot(data_training_cole.loc[:, 'epoch'], data_training_cole.loc[:, 'val_loss'], label='Validation Mean Absolute Error Cole model', color='red')
plt.legend(loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)
plt.title('Evolution of the error during the training using raw data')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error (age)')
plt.show()

# %% [markdown]
# On peut voir que plus d'itération ont permi à notre modèle plus complexe d'être plus performant que notre premier modèle. Nos modèles souffre de sur-apprentissage. Pour augmenter nos performances par la suite il faudrait utiliser des techniques de régularisation, ou d'obtenir plus de données.
